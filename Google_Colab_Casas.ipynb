# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernanda-mafe/Inform-tica/blob/main/Google_Colab_Casas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("greenwing1985/housepricing")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 4.57M/4.57M [00:00<00:00, 116MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/greenwing1985/housepricing/versions/1

# %%
# prompt: ler em dataframe os dados

import os
import pandas as pd

# Assuming the downloaded file is a CSV and its name is 'house_prices.csv'
# You might need to check the actual file name in the downloaded path
file_path = os.path.join(path, 'HousePrices_HalfMil.csv')

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the first 5 rows of the DataFrame
print(df.head())
# Out:
#    Area  Garage  FirePlace  Baths  White Marble  Black Marble  Indian Marble  \
# 0   164       2          0      2             0             1              0
# 1    84       2          0      4             0             0              1
# 2   190       2          4      4             1             0              0
# 3    75       2          4      4             0             0              1
# 4   148       1          4      2             1             0              0
#
#    Floors  City  Solar  Electric  Fiber  Glass Doors  Swiming Pool  Garden  \
# 0       0     3      1         1      1            1             0       0
# 1       1     2      0         0      0            1             1       1
# 2       0     2      0         0      1            0             0       0
# 3       1     1      1         1      1            1             1       1
# 4       1     2      1         0      0            1             1       1
#
#    Prices
# 0   43800
# 1   37550
# 2   49500
# ...

# %%
df.head()
# Out:
#    Area  Garage  FirePlace  Baths  White Marble  Black Marble  Indian Marble  \
# 0   164       2          0      2             0             1              0
# 1    84       2          0      4             0             0              1
# 2   190       2          4      4             1             0              0
# 3    75       2          4      4             0             0              1
# 4   148       1          4      2             1             0              0
#
#    Floors  City  Solar  Electric  Fiber  Glass Doors  Swiming Pool  Garden  \
# 0       0     3      1         1      1            1             0       0
# 1       1     2      0         0      0            1             1       1
# 2       0     2      0         0      1            0             0       0
# 3       1     1      1         1      1            1             1       1
# 4       1     2      1         0      0            1             1       1
#
#    Prices
# 0   43800
# 1   37550
# 2   49500
# ...
